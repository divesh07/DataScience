# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
word = tf.constant('Hello World')

# %%
word
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'Hello World'>

# %% [markdown]
# * In the output itself we can see the result due to Eager execution which was not the case with TF 1.14 due to lazy execution
# * We didn't have to exlicity create session

# %%
tf.print(word) # We can use this new fn 'print' with tf
# Out:
# Hello World
