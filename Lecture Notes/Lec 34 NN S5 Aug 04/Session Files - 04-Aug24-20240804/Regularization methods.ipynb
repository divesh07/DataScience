# %% [markdown]
# # Regularization

# %% [markdown]
# Overfitting, also known as High Variance, occurs when a model learns the training data too well but fail to generalize to new data.

# %% [markdown]
# ## Regularization Techniques

# %% [markdown]
# #### Regularization refers to a set of different techniques that lower the complexity of a neural network model during training, and thus minimize/prevent the overfitting.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Importing the useful files

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
iris = load_iris()

# %% [markdown]
# ## Exploring data

# %%
# Load data into a DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# Convert datatype to float
df = df.astype(float)
# append "target" and name it "label"
df['label'] = iris.target
# Use string label instead
df['label'] = df.label.replace(dict(enumerate(iris.target_names)))

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#     label
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ### Preparing data for Keras and TensorFlow

# %%
# label -> one-hot encoding
label = pd.get_dummies(df['label'], prefix='label')
df = pd.concat([df, label], axis=1)
# drop old label
df.drop(['label'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label_setosa  label_versicolor  label_virginica
# 0             1                 0                0
# 1             1                 0                0
# 2             1                 0                0
# 3             1                 0                0
# 4             1                 0                0

# %%
# Creating X and y

X = df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
# Convert DataFrame into np array
X = np.asarray(X)

y = df[['label_setosa', 'label_versicolor', 'label_virginica']]
# Convert DataFrame into np array
y = np.asarray(y)

# %%
# Split the data set in a training set (80%) and a test set (20%)
X_train, X_test, y_train, y_test = train_test_split(
  X,
  y,
  test_size=0.20
)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120, 3)
# (30, 3)

# %% [markdown]
# ## 1. Build an unregularized neural network model

# %% [markdown]
# 1. Build an unregularized neural network model
#
# Before applying regularization, let’s build a neural network without regularization and take a look at the overfitting issue.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

## def create_model(): 
model = Sequential([
        Dense(64, activation='relu', input_shape=(4,)),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(64, activation='relu'),
        Dense(3, activation='softmax'),
    ])
    ## return model

# %% [markdown]
#     The first layer (also known as the input layer) has the input_shape to set the input size (4,)
#     The input layer has 64 units, followed by 3 dense layers, each with 128 units.
#     Then there are further 3 dense layers, each with 64 units.
#     All these layers use the ReLU activation function.
#     The output Dense layer has 3 units and the softmax activation function.

# %%
##model = model_1
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 58,435
# Trainable params: 58,435
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 1.1 Training a model
#
# In order to train a model, we first have to configure our model using compile() and pass the following arguments:
#
#     Use Adam (adam) optimization algorithm as the optimizer
#     Use categorical cross-entropy loss function (categorical_crossentropy) for our multiple-class classification problem
#     For simplicity, use accuracy as our evaluation metrics to evaluate the model during training and testing.

# %% [markdown]
# ### Compile the model

# %%
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %% [markdown]
# ### Fit the model to the training data

# %%
history = model.fit(
    X_train, 
    y_train, 
    epochs=200, 
    validation_split=0.25, 
    batch_size=20, 
    verbose=2
)
# Out:
# Epoch 1/200
# 5/5 - 0s - loss: 0.1260 - accuracy: 0.9667 - val_loss: 0.0389 - val_accuracy: 0.9667 - 166ms/epoch - 33ms/step
# Epoch 2/200
# 5/5 - 0s - loss: 0.0967 - accuracy: 0.9778 - val_loss: 0.0324 - val_accuracy: 1.0000 - 112ms/epoch - 22ms/step
# Epoch 3/200
# 5/5 - 0s - loss: 0.0648 - accuracy: 0.9889 - val_loss: 0.0223 - val_accuracy: 1.0000 - 122ms/epoch - 24ms/step
# Epoch 4/200
# 5/5 - 0s - loss: 0.0850 - accuracy: 0.9778 - val_loss: 0.0178 - val_accuracy: 1.0000 - 111ms/epoch - 22ms/step
# Epoch 5/200
# 5/5 - 0s - loss: 0.0791 - accuracy: 0.9778 - val_loss: 0.0185 - val_accuracy: 1.0000 - 97ms/epoch - 19ms/step
# Epoch 6/200
# 5/5 - 0s - loss: 0.0634 - accuracy: 0.9889 - val_loss: 0.0427 - val_accuracy: 0.9667 - 105ms/epoch - 21ms/step
# Epoch 7/200
# 5/5 - 0s - loss: 0.0605 - accuracy: 0.9889 - val_loss: 0.0438 - val_accuracy: 0.9667 - 125ms/epoch - 25ms/step
# Epoch 8/200
# 5/5 - 0s - loss: 0.1334 - accuracy: 0.9556 - val_loss: 0.0237 - val_accuracy: 1.0000 - 101ms/epoch - 20ms/step
# Epoch 9/200
# 5/5 - 0s - loss: 0.1091 - accuracy: 0.9778 - val_loss: 0.0189 - val_accuracy: 1.0000 - 140ms/epoch - 28ms/step
# Epoch 10/200
# 5/5 - 0s - loss: 0.0684 - accuracy: 0.9889 - val_loss: 0.0410 - val_accuracy: 0.9667 - 116ms/epoch - 23ms/step
# Epoch 11/200
# 5/5 - 0s - loss: 0.0832 - accuracy: 0.9444 - val_loss: 0.0487 - val_accuracy: 0.9667 - 121ms/epoch - 24ms/step
# Epoch 12/200
# 5/5 - 0s - loss: 0.0786 - accuracy: 0.9778 - val_loss: 0.0495 - val_accuracy: 0.9667 - 107ms/epoch - 21ms/step
# Epoch 13/200
# 5/5 - 0s - loss: 0.0837 - accuracy: 0.9667 - val_loss: 0.0443 - val_accuracy: 0.9667 - 111ms/epoch - 22ms/step
# Epoch 14/200
# 5/5 - 0s - loss: 0.0585 - accuracy: 0.9889 - val_loss: 0.0430 - val_accuracy: 0.9667 - 110ms/epoch - 22ms/step
# Epoch 15/200
# 5/5 - 0s - loss: 0.0840 - accuracy: 0.9667 - val_loss: 0.0425 - val_accuracy: 0.9667 - 117ms/epoch - 23ms/step
# Epoch 16/200
# 5/5 - 0s - loss: 0.1015 - accuracy: 0.9778 - val_loss: 0.0208 - val_accuracy: 1.0000 - 110ms/epoch - 22ms/step
# Epoch 17/200
# 5/5 - 0s - loss: 0.1358 - accuracy: 0.9667 - val_loss: 0.0178 - val_accuracy: 1.0000 - 114ms/epoch - 23ms/step
# Epoch 18/200
# 5/5 - 0s - loss: 0.0901 - accuracy: 0.9778 - val_loss: 0.0301 - val_accuracy: 1.0000 - 114ms/epoch - 23ms/step
# Epoch 19/200
# 5/5 - 0s - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 1.0000 - 107ms/epoch - 21ms/step
# Epoch 20/200
# 5/5 - 0s - loss: 0.0866 - accuracy: 0.9667 - val_loss: 0.0162 - val_accuracy: 1.0000 - 107ms/epoch - 21ms/step
# Epoch 21/200
# 5/5 - 0s - loss: 0.0488 - accuracy: 0.9889 - val_loss: 0.0141 - val_accuracy: 1.0000 - 111ms/epoch - 22ms/step
# Epoch 22/200
# 5/5 - 0s - loss: 0.0692 - accuracy: 0.9778 - val_loss: 0.0216 - val_accuracy: 1.0000 - 103ms/epoch - 21ms/step
# Epoch 23/200
# 5/5 - 0s - loss: 0.0757 - accuracy: 0.9778 - val_loss: 0.0141 - val_accuracy: 1.0000 - 104ms/epoch - 21ms/step
# Epoch 24/200
# 5/5 - 0s - loss: 0.0858 - accuracy: 0.9778 - val_loss: 0.0324 - val_accuracy: 0.9667 - 102ms/epoch - 20ms/step
# Epoch 25/200
# 5/5 - 0s - loss: 0.1167 - accuracy: 0.9889 - val_loss: 0.0332 - val_accuracy: 0.9667 - 99ms/epoch - 20ms/step
# Epoch 26/200
# 5/5 - 0s - loss: 0.0680 - accuracy: 0.9778 - val_loss: 0.0277 - val_accuracy: 1.0000 - 96ms/epoch - 19ms/step
# Epoch 27/200
# 5/5 - 0s - loss: 0.0568 - accuracy: 0.9889 - val_loss: 0.0218 - val_accuracy: 1.0000 - 93ms/epoch - 19ms/step
# Epoch 28/200
# 5/5 - 0s - loss: 0.0782 - accuracy: 0.9778 - val_loss: 0.0145 - val_accuracy: 1.0000 - 88ms/epoch - 18ms/step
# Epoch 29/200
# 5/5 - 0s - loss: 0.0779 - accuracy: 0.9778 - val_loss: 0.0182 - val_accuracy: 1.0000 - 117ms/epoch - 23ms/step
# Epoch 30/200
# 5/5 - 0s - loss: 0.0475 - accuracy: 0.9889 - val_loss: 0.0253 - val_accuracy: 1.0000 - 107ms/epoch - 21ms/step
# Epoch 31/200
# 5/5 - 0s - loss: 0.0336 - accuracy: 0.9889 - val_loss: 0.0185 - val_accuracy: 1.0000 - 141ms/epoch - 28ms/step
# Epoch 32/200
# 5/5 - 0s - loss: 0.0589 - accuracy: 0.9889 - val_loss: 0.0094 - val_accuracy: 1.0000 - 186ms/epoch - 37ms/step
# Epoch 33/200
# 5/5 - 0s - loss: 0.1194 - accuracy: 0.9667 - val_loss: 0.0089 - val_accuracy: 1.0000 - 161ms/epoch - 32ms/step
# Epoch 34/200
# 5/5 - 0s - loss: 0.0517 - accuracy: 0.9889 - val_loss: 0.0107 - val_accuracy: 1.0000 - 118ms/epoch - 24ms/step
# Epoch 35/200
# 5/5 - 0s - loss: 0.1036 - accuracy: 0.9667 - val_loss: 0.0097 - val_accuracy: 1.0000 - 114ms/epoch - 23ms/step
# Epoch 36/200
# 5/5 - 0s - loss: 0.0907 - accuracy: 0.9778 - val_loss: 0.0154 - val_accuracy: 1.0000 - 147ms/epoch - 29ms/step
# Epoch 37/200
# 5/5 - 0s - loss: 0.0644 - accuracy: 0.9778 - val_loss: 0.0138 - val_accuracy: 1.0000 - 207ms/epoch - 41ms/step
# Epoch 38/200
# 5/5 - 0s - loss: 0.1154 - accuracy: 0.9778 - val_loss: 0.0442 - val_accuracy: 0.9667 - 258ms/epoch - 52ms/step
# Epoch 39/200
# 5/5 - 0s - loss: 0.0765 - accuracy: 0.9778 - val_loss: 0.0573 - val_accuracy: 0.9667 - 169ms/epoch - 34ms/step
# Epoch 40/200
# 5/5 - 0s - loss: 0.1211 - accuracy: 0.9667 - val_loss: 0.0452 - val_accuracy: 0.9667 - 135ms/epoch - 27ms/step
# Epoch 41/200
# 5/5 - 0s - loss: 0.0823 - accuracy: 0.9778 - val_loss: 0.0186 - val_accuracy: 1.0000 - 117ms/epoch - 23ms/step
# Epoch 42/200
# 5/5 - 0s - loss: 0.0472 - accuracy: 0.9889 - val_loss: 0.0124 - val_accuracy: 1.0000 - 115ms/epoch - 23ms/step
# Epoch 43/200
# 5/5 - 0s - loss: 0.0849 - accuracy: 0.9667 - val_loss: 0.0121 - val_accuracy: 1.0000 - 108ms/epoch - 22ms/step
# Epoch 44/200
# 5/5 - 0s - loss: 0.0803 - accuracy: 0.9889 - val_loss: 0.0208 - val_accuracy: 1.0000 - 119ms/epoch - 24ms/step
# Epoch 45/200
# 5/5 - 0s - loss: 0.0576 - accuracy: 0.9778 - val_loss: 0.0312 - val_accuracy: 0.9667 - 124ms/epoch - 25ms/step
# Epoch 46/200
# 5/5 - 0s - loss: 0.1020 - accuracy: 0.9778 - val_loss: 0.0231 - val_accuracy: 1.0000 - 107ms/epoch - 21ms/step
# Epoch 47/200
# 5/5 - 0s - loss: 0.0521 - accuracy: 0.9778 - val_loss: 0.0151 - val_accuracy: 1.0000 - 96ms/epoch - 19ms/step
# Epoch 48/200
# 5/5 - 0s - loss: 0.1020 - accuracy: 0.9778 - val_loss: 0.0299 - val_accuracy: 1.0000 - 104ms/epoch - 21ms/step
# Epoch 49/200
# 5/5 - 0s - loss: 0.0717 - accuracy: 0.9667 - val_loss: 0.0527 - val_accuracy: 0.9667 - 100ms/epoch - 20ms/step
# Epoch 50/200
# 5/5 - 0s - loss: 0.0977 - accuracy: 0.9778 - val_loss: 0.0499 - val_accuracy: 0.9667 - 103ms/epoch - 21ms/step
# Epoch 51/200
# 5/5 - 0s - loss: 0.0796 - accuracy: 0.9667 - val_loss: 0.0329 - val_accuracy: 0.9667 - 117ms/epoch - 23ms/step
# Epoch 52/200
# 5/5 - 0s - loss: 0.0941 - accuracy: 0.9778 - val_loss: 0.0179 - val_accuracy: 1.0000 - 123ms/epoch - 25ms/step
# Epoch 53/200
# 5/5 - 0s - loss: 0.0717 - accuracy: 0.9889 - val_loss: 0.0138 - val_accuracy: 1.0000 - 112ms/epoch - 22ms/step
# Epoch 54/200
# 5/5 - 0s - loss: 0.1027 - accuracy: 0.9667 - val_loss: 0.0146 - val_accuracy: 1.0000 - 105ms/epoch - 21ms/step
# Epoch 55/200
# 5/5 - 0s - loss: 0.0727 - accuracy: 0.9778 - val_loss: 0.0363 - val_accuracy: 0.9667 - 101ms/epoch - 20ms/step
# Epoch 56/200
# 5/5 - 0s - loss: 0.1104 - accuracy: 0.9778 - val_loss: 0.0431 - val_accuracy: 0.9667 - 117ms/epoch - 23ms/step
# Epoch 57/200
# 5/5 - 0s - loss: 0.0621 - accuracy: 0.9889 - val_loss: 0.0448 - val_accuracy: 0.9667 - 88ms/epoch - 18ms/step
# Epoch 58/200
# 5/5 - 0s - loss: 0.0882 - accuracy: 0.9667 - val_loss: 0.0381 - val_accuracy: 0.9667 - 76ms/epoch - 15ms/step
# Epoch 59/200
# 5/5 - 0s - loss: 0.0717 - accuracy: 0.9667 - val_loss: 0.0139 - val_accuracy: 1.0000 - 81ms/epoch - 16ms/step
# Epoch 60/200
# 5/5 - 0s - loss: 0.0941 - accuracy: 0.9667 - val_loss: 0.0126 - val_accuracy: 1.0000 - 98ms/epoch - 20ms/step
# Epoch 61/200
# 5/5 - 0s - loss: 0.1160 - accuracy: 0.9556 - val_loss: 0.0126 - val_accuracy: 1.0000 - 115ms/epoch - 23ms/step
# Epoch 62/200
# 5/5 - 0s - loss: 0.1114 - accuracy: 0.9667 - val_loss: 0.0214 - val_accuracy: 1.0000 - 94ms/epoch - 19ms/step
# Epoch 63/200
# 5/5 - 0s - loss: 0.0641 - accuracy: 0.9778 - val_loss: 0.0404 - val_accuracy: 0.9667 - 97ms/epoch - 19ms/step
# Epoch 64/200
# 5/5 - 0s - loss: 0.0606 - accuracy: 0.9778 - val_loss: 0.0420 - val_accuracy: 0.9667 - 85ms/epoch - 17ms/step
# Epoch 65/200
# 5/5 - 0s - loss: 0.0375 - accuracy: 0.9778 - val_loss: 0.0366 - val_accuracy: 0.9667 - 89ms/epoch - 18ms/step
# Epoch 66/200
# 5/5 - 0s - loss: 0.0815 - accuracy: 0.9778 - val_loss: 0.0292 - val_accuracy: 1.0000 - 99ms/epoch - 20ms/step
# Epoch 67/200
# 5/5 - 0s - loss: 0.0641 - accuracy: 0.9667 - val_loss: 0.0239 - val_accuracy: 1.0000 - 95ms/epoch - 19ms/step
# Epoch 68/200
# 5/5 - 0s - loss: 0.0618 - accuracy: 0.9889 - val_loss: 0.0173 - val_accuracy: 1.0000 - 97ms/epoch - 19ms/step
# Epoch 69/200
# 5/5 - 0s - loss: 0.0624 - accuracy: 0.9667 - val_loss: 0.0143 - val_accuracy: 1.0000 - 83ms/epoch - 17ms/step
# Epoch 70/200
# 5/5 - 0s - loss: 0.0843 - accuracy: 0.9667 - val_loss: 0.0110 - val_accuracy: 1.0000 - 87ms/epoch - 17ms/step
# Epoch 71/200
# 5/5 - 0s - loss: 0.0600 - accuracy: 0.9889 - val_loss: 0.0113 - val_accuracy: 1.0000 - 87ms/epoch - 17ms/step
# Epoch 72/200
# 5/5 - 0s - loss: 0.0627 - accuracy: 0.9778 - val_loss: 0.0154 - val_accuracy: 1.0000 - 82ms/epoch - 16ms/step
# Epoch 73/200
# 5/5 - 0s - loss: 0.0558 - accuracy: 0.9889 - val_loss: 0.0296 - val_accuracy: 1.0000 - 91ms/epoch - 18ms/step
# Epoch 74/200
# 5/5 - 0s - loss: 0.1047 - accuracy: 0.9667 - val_loss: 0.0297 - val_accuracy: 1.0000 - 88ms/epoch - 18ms/step
# Epoch 75/200
# 5/5 - 0s - loss: 0.0745 - accuracy: 0.9667 - val_loss: 0.0121 - val_accuracy: 1.0000 - 79ms/epoch - 16ms/step
# Epoch 76/200
# 5/5 - 0s - loss: 0.0396 - accuracy: 0.9889 - val_loss: 0.0102 - val_accuracy: 1.0000 - 92ms/epoch - 18ms/step
# Epoch 77/200
# 5/5 - 0s - loss: 0.0718 - accuracy: 0.9556 - val_loss: 0.0095 - val_accuracy: 1.0000 - 81ms/epoch - 16ms/step
# Epoch 78/200
# 5/5 - 0s - loss: 0.0827 - accuracy: 0.9778 - val_loss: 0.0114 - val_accuracy: 1.0000 - 81ms/epoch - 16ms/step
# Epoch 79/200
# 5/5 - 0s - loss: 0.0836 - accuracy: 0.9778 - val_loss: 0.0556 - val_accuracy: 0.9667 - 82ms/epoch - 16ms/step
# Epoch 80/200
# 5/5 - 0s - loss: 0.1360 - accuracy: 0.9667 - val_loss: 0.0709 - val_accuracy: 0.9667 - 91ms/epoch - 18ms/step
# Epoch 81/200
# 5/5 - 0s - loss: 0.0944 - accuracy: 0.9556 - val_loss: 0.0525 - val_accuracy: 0.9667 - 91ms/epoch - 18ms/step
# Epoch 82/200
# 5/5 - 0s - loss: 0.1405 - accuracy: 0.9556 - val_loss: 0.0335 - val_accuracy: 1.0000 - 120ms/epoch - 24ms/step
# Epoch 83/200
# 5/5 - 0s - loss: 0.0682 - accuracy: 0.9889 - val_loss: 0.0189 - val_accuracy: 1.0000 - 111ms/epoch - 22ms/step
# Epoch 84/200
# 5/5 - 0s - loss: 0.0771 - accuracy: 0.9778 - val_loss: 0.0161 - val_accuracy: 1.0000 - 106ms/epoch - 21ms/step
# Epoch 85/200
# 5/5 - 0s - loss: 0.0949 - accuracy: 0.9778 - val_loss: 0.0335 - val_accuracy: 0.9667 - 106ms/epoch - 21ms/step
# Epoch 86/200
# 5/5 - 0s - loss: 0.1017 - accuracy: 0.9556 - val_loss: 0.0481 - val_accuracy: 0.9667 - 92ms/epoch - 18ms/step
# Epoch 87/200
# 5/5 - 0s - loss: 0.1498 - accuracy: 0.9667 - val_loss: 0.0423 - val_accuracy: 0.9667 - 109ms/epoch - 22ms/step
# Epoch 88/200
# 5/5 - 0s - loss: 0.0988 - accuracy: 0.9667 - val_loss: 0.0330 - val_accuracy: 1.0000 - 106ms/epoch - 21ms/step
# Epoch 89/200
# 5/5 - 0s - loss: 0.0710 - accuracy: 0.9889 - val_loss: 0.0245 - val_accuracy: 1.0000 - 84ms/epoch - 17ms/step
# Epoch 90/200
# 5/5 - 0s - loss: 0.0677 - accuracy: 0.9889 - val_loss: 0.0212 - val_accuracy: 1.0000 - 85ms/epoch - 17ms/step
# Epoch 91/200
# 5/5 - 0s - loss: 0.2186 - accuracy: 0.9556 - val_loss: 0.0232 - val_accuracy: 1.0000 - 86ms/epoch - 17ms/step
# Epoch 92/200
# 5/5 - 0s - loss: 0.1035 - accuracy: 0.9667 - val_loss: 0.0365 - val_accuracy: 0.9667 - 85ms/epoch - 17ms/step
# Epoch 93/200
# 5/5 - 0s - loss: 0.0965 - accuracy: 0.9667 - val_loss: 0.0424 - val_accuracy: 0.9667 - 91ms/epoch - 18ms/step
# Epoch 94/200
# 5/5 - 0s - loss: 0.0691 - accuracy: 0.9667 - val_loss: 0.0402 - val_accuracy: 0.9667 - 97ms/epoch - 19ms/step
# Epoch 95/200
# 5/5 - 0s - loss: 0.0979 - accuracy: 0.9667 - val_loss: 0.0322 - val_accuracy: 1.0000 - 88ms/epoch - 18ms/step
# Epoch 96/200
# 5/5 - 0s - loss: 0.0657 - accuracy: 0.9778 - val_loss: 0.0227 - val_accuracy: 1.0000 - 93ms/epoch - 19ms/step
# Epoch 97/200
# 5/5 - 0s - loss: 0.0631 - accuracy: 0.9778 - val_loss: 0.0178 - val_accuracy: 1.0000 - 137ms/epoch - 27ms/step
# Epoch 98/200
# 5/5 - 0s - loss: 0.0728 - accuracy: 0.9667 - val_loss: 0.0161 - val_accuracy: 1.0000 - 114ms/epoch - 23ms/step
# Epoch 99/200
# 5/5 - 0s - loss: 0.0830 - accuracy: 0.9556 - val_loss: 0.0189 - val_accuracy: 1.0000 - 136ms/epoch - 27ms/step
# Epoch 100/200
# 5/5 - 0s - loss: 0.0419 - accuracy: 0.9889 - val_loss: 0.0176 - val_accuracy: 1.0000 - 119ms/epoch - 24ms/step
# Epoch 101/200
# 5/5 - 0s - loss: 0.0741 - accuracy: 0.9778 - val_loss: 0.0115 - val_accuracy: 1.0000 - 84ms/epoch - 17ms/step
# Epoch 102/200
# 5/5 - 0s - loss: 0.0551 - accuracy: 0.9778 - val_loss: 0.0102 - val_accuracy: 1.0000 - 85ms/epoch - 17ms/step
# Epoch 103/200
# 5/5 - 0s - loss: 0.0772 - accuracy: 0.9778 - val_loss: 0.0102 - val_accuracy: 1.0000 - 97ms/epoch - 19ms/step
# Epoch 104/200
# 5/5 - 0s - loss: 0.0654 - accuracy: 0.9778 - val_loss: 0.0107 - val_accuracy: 1.0000 - 158ms/epoch - 32ms/step
# Epoch 105/200
# 5/5 - 0s - loss: 0.0991 - accuracy: 0.9778 - val_loss: 0.0169 - val_accuracy: 1.0000 - 148ms/epoch - 30ms/step
# Epoch 106/200
# 5/5 - 0s - loss: 0.1176 - accuracy: 0.9556 - val_loss: 0.0216 - val_accuracy: 1.0000 - 120ms/epoch - 24ms/step
# Epoch 107/200
# 5/5 - 0s - loss: 0.0368 - accuracy: 0.9889 - val_loss: 0.0248 - val_accuracy: 1.0000 - 97ms/epoch - 19ms/step
# Epoch 108/200
# 5/5 - 0s - loss: 0.0435 - accuracy: 0.9778 - val_loss: 0.0296 - val_accuracy: 1.0000 - 96ms/epoch - 19ms/step
# Epoch 109/200
# 5/5 - 0s - loss: 0.0479 - accuracy: 0.9889 - val_loss: 0.0308 - val_accuracy: 0.9667 - 95ms/epoch - 19ms/step
# Epoch 110/200
# 5/5 - 0s - loss: 0.1558 - accuracy: 0.9667 - val_loss: 0.0247 - val_accuracy: 1.0000 - 81ms/epoch - 16ms/step
# Epoch 111/200
# 5/5 - 0s - loss: 0.0864 - accuracy: 0.9889 - val_loss: 0.0177 - val_accuracy: 1.0000 - 91ms/epoch - 18ms/step
# Epoch 112/200
# 5/5 - 0s - loss: 0.0595 - accuracy: 0.9889 - val_loss: 0.0165 - val_accuracy: 1.0000 - 88ms/epoch - 18ms/step
# Epoch 113/200
# 5/5 - 0s - loss: 0.0909 - accuracy: 0.9778 - val_loss: 0.0236 - val_accuracy: 1.0000 - 89ms/epoch - 18ms/step
# Epoch 114/200
# 5/5 - 0s - loss: 0.0610 - accuracy: 0.9778 - val_loss: 0.0396 - val_accuracy: 0.9667 - 102ms/epoch - 20ms/step
# Epoch 115/200
# 5/5 - 0s - loss: 0.0538 - accuracy: 0.9889 - val_loss: 0.0409 - val_accuracy: 0.9667 - 177ms/epoch - 35ms/step
# Epoch 116/200
# 5/5 - 0s - loss: 0.0660 - accuracy: 0.9778 - val_loss: 0.0359 - val_accuracy: 0.9667 - 157ms/epoch - 31ms/step
# Epoch 117/200
# 5/5 - 0s - loss: 0.1256 - accuracy: 0.9778 - val_loss: 0.0210 - val_accuracy: 1.0000 - 121ms/epoch - 24ms/step
# Epoch 118/200
# 5/5 - 0s - loss: 0.0861 - accuracy: 0.9667 - val_loss: 0.0188 - val_accuracy: 1.0000 - 147ms/epoch - 29ms/step
# Epoch 119/200
# 5/5 - 0s - loss: 0.0571 - accuracy: 0.9889 - val_loss: 0.0266 - val_accuracy: 1.0000 - 179ms/epoch - 36ms/step
# Epoch 120/200
# 5/5 - 0s - loss: 0.0869 - accuracy: 0.9667 - val_loss: 0.0338 - val_accuracy: 0.9667 - 187ms/epoch - 37ms/step
# Epoch 121/200
# 5/5 - 0s - loss: 0.0578 - accuracy: 0.9778 - val_loss: 0.0186 - val_accuracy: 1.0000 - 184ms/epoch - 37ms/step
# Epoch 122/200
# 5/5 - 0s - loss: 0.0601 - accuracy: 0.9889 - val_loss: 0.0137 - val_accuracy: 1.0000 - 219ms/epoch - 44ms/step
# Epoch 123/200
# 5/5 - 0s - loss: 0.1289 - accuracy: 0.9667 - val_loss: 0.0378 - val_accuracy: 0.9667 - 171ms/epoch - 34ms/step
# Epoch 124/200
# 5/5 - 0s - loss: 0.0683 - accuracy: 0.9778 - val_loss: 0.1077 - val_accuracy: 0.9667 - 156ms/epoch - 31ms/step
# Epoch 125/200
# 5/5 - 0s - loss: 0.1167 - accuracy: 0.9667 - val_loss: 0.0810 - val_accuracy: 0.9667 - 180ms/epoch - 36ms/step
# Epoch 126/200
# 5/5 - 0s - loss: 0.1235 - accuracy: 0.9444 - val_loss: 0.0384 - val_accuracy: 0.9667 - 159ms/epoch - 32ms/step
# Epoch 127/200
# 5/5 - 0s - loss: 0.0693 - accuracy: 0.9778 - val_loss: 0.0275 - val_accuracy: 1.0000 - 163ms/epoch - 33ms/step
# Epoch 128/200
# 5/5 - 0s - loss: 0.0868 - accuracy: 0.9556 - val_loss: 0.0271 - val_accuracy: 1.0000 - 174ms/epoch - 35ms/step
# Epoch 129/200
# 5/5 - 0s - loss: 0.0891 - accuracy: 0.9667 - val_loss: 0.0341 - val_accuracy: 1.0000 - 144ms/epoch - 29ms/step
# Epoch 130/200
# 5/5 - 0s - loss: 0.0780 - accuracy: 0.9889 - val_loss: 0.0351 - val_accuracy: 1.0000 - 131ms/epoch - 26ms/step
# Epoch 131/200
# 5/5 - 0s - loss: 0.0724 - accuracy: 0.9667 - val_loss: 0.0345 - val_accuracy: 1.0000 - 145ms/epoch - 29ms/step
# Epoch 132/200
# 5/5 - 0s - loss: 0.0839 - accuracy: 0.9778 - val_loss: 0.0302 - val_accuracy: 1.0000 - 125ms/epoch - 25ms/step
# Epoch 133/200
# 5/5 - 0s - loss: 0.1030 - accuracy: 0.9778 - val_loss: 0.0254 - val_accuracy: 1.0000 - 113ms/epoch - 23ms/step
# Epoch 134/200
# 5/5 - 0s - loss: 0.0488 - accuracy: 0.9889 - val_loss: 0.0247 - val_accuracy: 1.0000 - 102ms/epoch - 20ms/step
# Epoch 135/200
# 5/5 - 0s - loss: 0.0579 - accuracy: 0.9778 - val_loss: 0.0324 - val_accuracy: 1.0000 - 93ms/epoch - 19ms/step
# Epoch 136/200
# 5/5 - 0s - loss: 0.0619 - accuracy: 0.9889 - val_loss: 0.0371 - val_accuracy: 0.9667 - 97ms/epoch - 19ms/step
# Epoch 137/200
# 5/5 - 0s - loss: 0.0590 - accuracy: 0.9778 - val_loss: 0.0424 - val_accuracy: 0.9667 - 101ms/epoch - 20ms/step
# Epoch 138/200
# 5/5 - 0s - loss: 0.0811 - accuracy: 0.9778 - val_loss: 0.0473 - val_accuracy: 0.9667 - 91ms/epoch - 18ms/step
# Epoch 139/200
# 5/5 - 0s - loss: 0.0751 - accuracy: 0.9778 - val_loss: 0.0391 - val_accuracy: 0.9667 - 98ms/epoch - 20ms/step
# Epoch 140/200
# 5/5 - 0s - loss: 0.0781 - accuracy: 0.9778 - val_loss: 0.0174 - val_accuracy: 1.0000 - 99ms/epoch - 20ms/step
# Epoch 141/200
# 5/5 - 0s - loss: 0.0634 - accuracy: 0.9778 - val_loss: 0.0162 - val_accuracy: 1.0000 - 90ms/epoch - 18ms/step
# Epoch 142/200
# 5/5 - 0s - loss: 0.0778 - accuracy: 0.9667 - val_loss: 0.0336 - val_accuracy: 0.9667 - 133ms/epoch - 27ms/step
# Epoch 143/200
# 5/5 - 0s - loss: 0.0636 - accuracy: 0.9667 - val_loss: 0.0433 - val_accuracy: 0.9667 - 152ms/epoch - 30ms/step
# Epoch 144/200
# 5/5 - 0s - loss: 0.0759 - accuracy: 0.9778 - val_loss: 0.0457 - val_accuracy: 0.9667 - 128ms/epoch - 26ms/step
# Epoch 145/200
# 5/5 - 0s - loss: 0.1084 - accuracy: 0.9778 - val_loss: 0.0395 - val_accuracy: 0.9667 - 125ms/epoch - 25ms/step
# Epoch 146/200
# 5/5 - 0s - loss: 0.0492 - accuracy: 0.9889 - val_loss: 0.0160 - val_accuracy: 1.0000 - 87ms/epoch - 17ms/step
# Epoch 147/200
# 5/5 - 0s - loss: 0.0732 - accuracy: 0.9778 - val_loss: 0.0199 - val_accuracy: 1.0000 - 99ms/epoch - 20ms/step
# Epoch 148/200
# 5/5 - 0s - loss: 0.0562 - accuracy: 0.9889 - val_loss: 0.0300 - val_accuracy: 1.0000 - 147ms/epoch - 29ms/step
# Epoch 149/200
# 5/5 - 0s - loss: 0.0603 - accuracy: 0.9889 - val_loss: 0.0299 - val_accuracy: 1.0000 - 114ms/epoch - 23ms/step
# Epoch 150/200
# 5/5 - 0s - loss: 0.0675 - accuracy: 0.9778 - val_loss: 0.0272 - val_accuracy: 1.0000 - 98ms/epoch - 20ms/step
# Epoch 151/200
# 5/5 - 0s - loss: 0.0854 - accuracy: 0.9667 - val_loss: 0.0291 - val_accuracy: 1.0000 - 84ms/epoch - 17ms/step
# Epoch 152/200
# 5/5 - 0s - loss: 0.0432 - accuracy: 0.9889 - val_loss: 0.0287 - val_accuracy: 1.0000 - 97ms/epoch - 19ms/step
# Epoch 153/200
# 5/5 - 0s - loss: 0.0951 - accuracy: 0.9778 - val_loss: 0.0221 - val_accuracy: 1.0000 - 95ms/epoch - 19ms/step
# Epoch 154/200
# 5/5 - 0s - loss: 0.0783 - accuracy: 0.9778 - val_loss: 0.0198 - val_accuracy: 1.0000 - 118ms/epoch - 24ms/step
# Epoch 155/200
# 5/5 - 0s - loss: 0.0632 - accuracy: 0.9889 - val_loss: 0.0370 - val_accuracy: 0.9667 - 131ms/epoch - 26ms/step
# Epoch 156/200
# 5/5 - 0s - loss: 0.0602 - accuracy: 0.9889 - val_loss: 0.0400 - val_accuracy: 0.9667 - 131ms/epoch - 26ms/step
# Epoch 157/200
# 5/5 - 0s - loss: 0.1038 - accuracy: 0.9889 - val_loss: 0.0368 - val_accuracy: 0.9667 - 115ms/epoch - 23ms/step
# Epoch 158/200
# 5/5 - 0s - loss: 0.0557 - accuracy: 0.9889 - val_loss: 0.0164 - val_accuracy: 1.0000 - 101ms/epoch - 20ms/step
# Epoch 159/200
# 5/5 - 0s - loss: 0.1663 - accuracy: 0.9556 - val_loss: 0.0316 - val_accuracy: 1.0000 - 106ms/epoch - 21ms/step
# Epoch 160/200
# 5/5 - 0s - loss: 0.0519 - accuracy: 0.9889 - val_loss: 0.1214 - val_accuracy: 0.9333 - 102ms/epoch - 20ms/step
# Epoch 161/200
# 5/5 - 0s - loss: 0.1228 - accuracy: 0.9333 - val_loss: 0.1548 - val_accuracy: 0.9000 - 90ms/epoch - 18ms/step
# Epoch 162/200
# 5/5 - 0s - loss: 0.2345 - accuracy: 0.9222 - val_loss: 0.0770 - val_accuracy: 0.9667 - 94ms/epoch - 19ms/step
# Epoch 163/200
# 5/5 - 0s - loss: 0.0893 - accuracy: 0.9667 - val_loss: 0.0439 - val_accuracy: 0.9667 - 147ms/epoch - 29ms/step
# Epoch 164/200
# 5/5 - 0s - loss: 0.1057 - accuracy: 0.9667 - val_loss: 0.0378 - val_accuracy: 1.0000 - 117ms/epoch - 23ms/step
# Epoch 165/200
# 5/5 - 0s - loss: 0.1060 - accuracy: 0.9556 - val_loss: 0.0345 - val_accuracy: 1.0000 - 120ms/epoch - 24ms/step
# Epoch 166/200
# 5/5 - 0s - loss: 0.0683 - accuracy: 0.9667 - val_loss: 0.0379 - val_accuracy: 1.0000 - 111ms/epoch - 22ms/step
# Epoch 167/200
# 5/5 - 0s - loss: 0.0942 - accuracy: 0.9667 - val_loss: 0.0393 - val_accuracy: 0.9667 - 111ms/epoch - 22ms/step
# Epoch 168/200
# 5/5 - 0s - loss: 0.0658 - accuracy: 0.9778 - val_loss: 0.0384 - val_accuracy: 0.9667 - 127ms/epoch - 25ms/step
# Epoch 169/200
# 5/5 - 0s - loss: 0.0488 - accuracy: 0.9889 - val_loss: 0.0356 - val_accuracy: 0.9667 - 141ms/epoch - 28ms/step
# Epoch 170/200
# 5/5 - 0s - loss: 0.0659 - accuracy: 0.9889 - val_loss: 0.0343 - val_accuracy: 0.9667 - 135ms/epoch - 27ms/step
# Epoch 171/200
# 5/5 - 0s - loss: 0.0692 - accuracy: 0.9778 - val_loss: 0.0370 - val_accuracy: 0.9667 - 94ms/epoch - 19ms/step
# Epoch 172/200
# 5/5 - 0s - loss: 0.0668 - accuracy: 0.9889 - val_loss: 0.0303 - val_accuracy: 1.0000 - 102ms/epoch - 20ms/step
# Epoch 173/200
# 5/5 - 0s - loss: 0.0487 - accuracy: 0.9889 - val_loss: 0.0273 - val_accuracy: 1.0000 - 104ms/epoch - 21ms/step
# Epoch 174/200
# 5/5 - 0s - loss: 0.1325 - accuracy: 0.9556 - val_loss: 0.0353 - val_accuracy: 1.0000 - 125ms/epoch - 25ms/step
# Epoch 175/200
# 5/5 - 0s - loss: 0.0542 - accuracy: 0.9778 - val_loss: 0.0313 - val_accuracy: 1.0000 - 118ms/epoch - 24ms/step
# Epoch 176/200
# 5/5 - 0s - loss: 0.0905 - accuracy: 0.9667 - val_loss: 0.0394 - val_accuracy: 0.9667 - 92ms/epoch - 18ms/step
# Epoch 177/200
# 5/5 - 0s - loss: 0.0421 - accuracy: 0.9778 - val_loss: 0.0435 - val_accuracy: 0.9667 - 92ms/epoch - 18ms/step
# Epoch 178/200
# 5/5 - 0s - loss: 0.0543 - accuracy: 0.9889 - val_loss: 0.0486 - val_accuracy: 0.9667 - 123ms/epoch - 25ms/step
# Epoch 179/200
# 5/5 - 0s - loss: 0.0744 - accuracy: 0.9556 - val_loss: 0.0441 - val_accuracy: 0.9667 - 90ms/epoch - 18ms/step
# Epoch 180/200
# 5/5 - 0s - loss: 0.0406 - accuracy: 0.9889 - val_loss: 0.0290 - val_accuracy: 1.0000 - 106ms/epoch - 21ms/step
# Epoch 181/200
# 5/5 - 0s - loss: 0.0511 - accuracy: 0.9889 - val_loss: 0.0145 - val_accuracy: 1.0000 - 93ms/epoch - 19ms/step
# Epoch 182/200
# 5/5 - 0s - loss: 0.0690 - accuracy: 0.9778 - val_loss: 0.0122 - val_accuracy: 1.0000 - 96ms/epoch - 19ms/step
# Epoch 183/200
# 5/5 - 0s - loss: 0.0749 - accuracy: 0.9889 - val_loss: 0.0122 - val_accuracy: 1.0000 - 95ms/epoch - 19ms/step
# Epoch 184/200
# 5/5 - 0s - loss: 0.0811 - accuracy: 0.9667 - val_loss: 0.0183 - val_accuracy: 1.0000 - 92ms/epoch - 18ms/step
# Epoch 185/200
# 5/5 - 0s - loss: 0.0499 - accuracy: 0.9778 - val_loss: 0.0176 - val_accuracy: 1.0000 - 90ms/epoch - 18ms/step
# Epoch 186/200
# 5/5 - 0s - loss: 0.0872 - accuracy: 0.9667 - val_loss: 0.0110 - val_accuracy: 1.0000 - 90ms/epoch - 18ms/step
# Epoch 187/200
# 5/5 - 0s - loss: 0.0476 - accuracy: 0.9889 - val_loss: 0.0167 - val_accuracy: 1.0000 - 88ms/epoch - 18ms/step
# Epoch 188/200
# 5/5 - 0s - loss: 0.1038 - accuracy: 0.9778 - val_loss: 0.0147 - val_accuracy: 1.0000 - 95ms/epoch - 19ms/step
# Epoch 189/200
# 5/5 - 0s - loss: 0.0598 - accuracy: 0.9778 - val_loss: 0.0150 - val_accuracy: 1.0000 - 101ms/epoch - 20ms/step
# Epoch 190/200
# 5/5 - 0s - loss: 0.0483 - accuracy: 0.9778 - val_loss: 0.0285 - val_accuracy: 1.0000 - 106ms/epoch - 21ms/step
# Epoch 191/200
# 5/5 - 0s - loss: 0.0724 - accuracy: 0.9889 - val_loss: 0.0371 - val_accuracy: 0.9667 - 83ms/epoch - 17ms/step
# Epoch 192/200
# 5/5 - 0s - loss: 0.0805 - accuracy: 0.9556 - val_loss: 0.0414 - val_accuracy: 0.9667 - 93ms/epoch - 19ms/step
# Epoch 193/200
# 5/5 - 0s - loss: 0.0322 - accuracy: 0.9889 - val_loss: 0.0392 - val_accuracy: 0.9667 - 99ms/epoch - 20ms/step
# Epoch 194/200
# 5/5 - 0s - loss: 0.0723 - accuracy: 0.9778 - val_loss: 0.0335 - val_accuracy: 0.9667 - 109ms/epoch - 22ms/step
# Epoch 195/200
# 5/5 - 0s - loss: 0.0672 - accuracy: 0.9667 - val_loss: 0.0297 - val_accuracy: 1.0000 - 89ms/epoch - 18ms/step
# Epoch 196/200
# 5/5 - 0s - loss: 0.0717 - accuracy: 0.9778 - val_loss: 0.0203 - val_accuracy: 1.0000 - 109ms/epoch - 22ms/step
# Epoch 197/200
# 5/5 - 0s - loss: 0.1418 - accuracy: 0.9556 - val_loss: 0.0423 - val_accuracy: 0.9667 - 112ms/epoch - 22ms/step
# Epoch 198/200
# 5/5 - 0s - loss: 0.1028 - accuracy: 0.9778 - val_loss: 0.0562 - val_accuracy: 0.9667 - 98ms/epoch - 20ms/step
# Epoch 199/200
# 5/5 - 0s - loss: 0.0733 - accuracy: 0.9778 - val_loss: 0.0496 - val_accuracy: 0.9667 - 96ms/epoch - 19ms/step
# Epoch 200/200
# 5/5 - 0s - loss: 0.0822 - accuracy: 0.9778 - val_loss: 0.0432 - val_accuracy: 0.9667 - 100ms/epoch - 20ms/step

# %% [markdown]
# ### Model Evaluation

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
plot_metric(history, 'accuracy')

# %%
plot_metric(history, 'loss')

# %% [markdown]
# ### Plot the training and validation loss
#
# plotting the loss vs. epochs graph on the training and validation sets
# From the graph, it can be seen that the model has vastly overfitted the training data, so it outperform the validation set

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0587 - accuracy: 0.9667 - 45ms/epoch - 45ms/step
# [0.058726780116558075, 0.9666666388511658]

# %% [markdown]
# ## 2. Adding L2 regularization and Dropout

# %% [markdown]
# ## Import Dropout and L2 regularization from TensorFlow Keras package

# %% [markdown]
# Create a function called create_regularized_model() that will return a model similar to the one we built before.
# However, L2 regularization and Dropout layers are added.
# The function will take 2 arguments: a L2 regularization factor and a Dropout rate.
#
#     Add L2 regularization in all layers except the output layer [1].
#     Add Dropout layer between every two dense layers.

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2 ##(L2 regularizer)

def create_regularized_model(factor, rate):
    model = Sequential([
        Dense(64, kernel_regularizer=l2(factor), activation="relu", input_shape=(4,)),
        Dropout(rate),
        Dense(128, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(128, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(128, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(64, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(64, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(64, kernel_regularizer=l2(factor), activation="relu"),
        Dropout(rate),
        Dense(3, activation='softmax')
    ])
    return model

# %%
# Re-build the model with weight decay and dropout layers
model = create_regularized_model(1e-5, 0.3)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                320
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_11 (Dense)            (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_15 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 58,435
# Trainable params: 58,435
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(
    optimizer='adam', 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
)

# %%
# Train the model, with some of the data reserved for validation
history = model.fit(
    X_train, 
    y_train, 
    epochs=100, 
    validation_split=0.25, 
    batch_size=20, 
    verbose=2
)
# Out:
# Epoch 1/100
# 5/5 - 0s - loss: 0.1401 - accuracy: 0.9444 - val_loss: 0.0781 - val_accuracy: 0.9667 - 160ms/epoch - 32ms/step
# Epoch 2/100
# 5/5 - 0s - loss: 0.0916 - accuracy: 0.9556 - val_loss: 0.0559 - val_accuracy: 0.9667 - 111ms/epoch - 22ms/step
# Epoch 3/100
# 5/5 - 0s - loss: 0.1228 - accuracy: 0.9556 - val_loss: 0.0448 - val_accuracy: 0.9667 - 116ms/epoch - 23ms/step
# Epoch 4/100
# 5/5 - 0s - loss: 0.1030 - accuracy: 0.9556 - val_loss: 0.0406 - val_accuracy: 0.9667 - 106ms/epoch - 21ms/step
# Epoch 5/100
# 5/5 - 0s - loss: 0.1227 - accuracy: 0.9778 - val_loss: 0.0375 - val_accuracy: 1.0000 - 115ms/epoch - 23ms/step
# Epoch 6/100
# 5/5 - 0s - loss: 0.1048 - accuracy: 0.9667 - val_loss: 0.0387 - val_accuracy: 0.9667 - 105ms/epoch - 21ms/step
# Epoch 7/100
# 5/5 - 0s - loss: 0.0815 - accuracy: 0.9778 - val_loss: 0.0445 - val_accuracy: 0.9667 - 100ms/epoch - 20ms/step
# Epoch 8/100
# 5/5 - 0s - loss: 0.0678 - accuracy: 0.9889 - val_loss: 0.0431 - val_accuracy: 0.9667 - 102ms/epoch - 20ms/step
# Epoch 9/100
# 5/5 - 0s - loss: 0.0821 - accuracy: 0.9667 - val_loss: 0.0422 - val_accuracy: 0.9667 - 128ms/epoch - 26ms/step
# Epoch 10/100
# 5/5 - 0s - loss: 0.0809 - accuracy: 0.9778 - val_loss: 0.0365 - val_accuracy: 0.9667 - 111ms/epoch - 22ms/step
# Epoch 11/100
# 5/5 - 0s - loss: 0.0789 - accuracy: 0.9778 - val_loss: 0.0359 - val_accuracy: 0.9667 - 177ms/epoch - 35ms/step
# Epoch 12/100
# 5/5 - 0s - loss: 0.1553 - accuracy: 0.9556 - val_loss: 0.0338 - val_accuracy: 0.9667 - 184ms/epoch - 37ms/step
# Epoch 13/100
# 5/5 - 0s - loss: 0.0793 - accuracy: 0.9778 - val_loss: 0.0310 - val_accuracy: 1.0000 - 140ms/epoch - 28ms/step
# Epoch 14/100
# 5/5 - 0s - loss: 0.0707 - accuracy: 0.9778 - val_loss: 0.0277 - val_accuracy: 1.0000 - 125ms/epoch - 25ms/step
# Epoch 15/100
# 5/5 - 0s - loss: 0.0886 - accuracy: 0.9556 - val_loss: 0.0330 - val_accuracy: 0.9667 - 120ms/epoch - 24ms/step
# Epoch 16/100
# 5/5 - 0s - loss: 0.0669 - accuracy: 0.9889 - val_loss: 0.0493 - val_accuracy: 0.9667 - 108ms/epoch - 22ms/step
# Epoch 17/100
# 5/5 - 0s - loss: 0.0567 - accuracy: 0.9778 - val_loss: 0.0521 - val_accuracy: 0.9667 - 114ms/epoch - 23ms/step
# Epoch 18/100
# 5/5 - 0s - loss: 0.0780 - accuracy: 0.9667 - val_loss: 0.0431 - val_accuracy: 0.9667 - 110ms/epoch - 22ms/step
# Epoch 19/100
# 5/5 - 0s - loss: 0.0898 - accuracy: 0.9556 - val_loss: 0.0395 - val_accuracy: 0.9667 - 104ms/epoch - 21ms/step
# Epoch 20/100
# 5/5 - 0s - loss: 0.0765 - accuracy: 0.9778 - val_loss: 0.0375 - val_accuracy: 0.9667 - 97ms/epoch - 19ms/step
# Epoch 21/100
# 5/5 - 0s - loss: 0.0827 - accuracy: 0.9778 - val_loss: 0.0350 - val_accuracy: 0.9667 - 103ms/epoch - 21ms/step
# Epoch 22/100
# 5/5 - 0s - loss: 0.0692 - accuracy: 0.9778 - val_loss: 0.0361 - val_accuracy: 0.9667 - 102ms/epoch - 20ms/step
# Epoch 23/100
# 5/5 - 0s - loss: 0.0537 - accuracy: 0.9778 - val_loss: 0.0369 - val_accuracy: 0.9667 - 110ms/epoch - 22ms/step
# Epoch 24/100
# 5/5 - 0s - loss: 0.0829 - accuracy: 0.9889 - val_loss: 0.0285 - val_accuracy: 1.0000 - 115ms/epoch - 23ms/step
# Epoch 25/100
# 5/5 - 0s - loss: 0.1440 - accuracy: 0.9778 - val_loss: 0.0191 - val_accuracy: 1.0000 - 111ms/epoch - 22ms/step
# Epoch 26/100
# 5/5 - 0s - loss: 0.1834 - accuracy: 0.9556 - val_loss: 0.0373 - val_accuracy: 0.9667 - 107ms/epoch - 21ms/step
# Epoch 27/100
# 5/5 - 0s - loss: 0.1086 - accuracy: 0.9556 - val_loss: 0.0390 - val_accuracy: 0.9667 - 110ms/epoch - 22ms/step
# Epoch 28/100
# 5/5 - 0s - loss: 0.0783 - accuracy: 0.9667 - val_loss: 0.0321 - val_accuracy: 1.0000 - 93ms/epoch - 19ms/step
# Epoch 29/100
# 5/5 - 0s - loss: 0.0627 - accuracy: 0.9778 - val_loss: 0.0264 - val_accuracy: 1.0000 - 99ms/epoch - 20ms/step
# Epoch 30/100
# 5/5 - 0s - loss: 0.0577 - accuracy: 0.9889 - val_loss: 0.0245 - val_accuracy: 1.0000 - 139ms/epoch - 28ms/step
# Epoch 31/100
# 5/5 - 0s - loss: 0.1116 - accuracy: 0.9778 - val_loss: 0.0165 - val_accuracy: 1.0000 - 134ms/epoch - 27ms/step
# Epoch 32/100
# 5/5 - 0s - loss: 0.0770 - accuracy: 0.9778 - val_loss: 0.0145 - val_accuracy: 1.0000 - 129ms/epoch - 26ms/step
# Epoch 33/100
# 5/5 - 0s - loss: 0.1076 - accuracy: 0.9778 - val_loss: 0.0297 - val_accuracy: 1.0000 - 95ms/epoch - 19ms/step
# Epoch 34/100
# 5/5 - 0s - loss: 0.0714 - accuracy: 0.9778 - val_loss: 0.0544 - val_accuracy: 0.9667 - 112ms/epoch - 22ms/step
# Epoch 35/100
# 5/5 - 0s - loss: 0.1219 - accuracy: 0.9444 - val_loss: 0.0587 - val_accuracy: 0.9667 - 114ms/epoch - 23ms/step
# Epoch 36/100
# 5/5 - 0s - loss: 0.1218 - accuracy: 0.9667 - val_loss: 0.0449 - val_accuracy: 0.9667 - 116ms/epoch - 23ms/step
# Epoch 37/100
# 5/5 - 0s - loss: 0.0683 - accuracy: 0.9667 - val_loss: 0.0428 - val_accuracy: 0.9667 - 121ms/epoch - 24ms/step
# Epoch 38/100
# 5/5 - 0s - loss: 0.0803 - accuracy: 0.9667 - val_loss: 0.0380 - val_accuracy: 0.9667 - 110ms/epoch - 22ms/step
# Epoch 39/100
# 5/5 - 0s - loss: 0.0954 - accuracy: 0.9667 - val_loss: 0.0395 - val_accuracy: 0.9667 - 113ms/epoch - 23ms/step
# Epoch 40/100
# 5/5 - 0s - loss: 0.0827 - accuracy: 0.9667 - val_loss: 0.0418 - val_accuracy: 0.9667 - 114ms/epoch - 23ms/step
# Epoch 41/100
# 5/5 - 0s - loss: 0.0720 - accuracy: 0.9778 - val_loss: 0.0418 - val_accuracy: 0.9667 - 99ms/epoch - 20ms/step
# Epoch 42/100
# 5/5 - 0s - loss: 0.1007 - accuracy: 0.9778 - val_loss: 0.0467 - val_accuracy: 0.9667 - 102ms/epoch - 20ms/step
# Epoch 43/100
# 5/5 - 0s - loss: 0.0976 - accuracy: 0.9667 - val_loss: 0.0448 - val_accuracy: 0.9667 - 109ms/epoch - 22ms/step
# Epoch 44/100
# 5/5 - 0s - loss: 0.1015 - accuracy: 0.9556 - val_loss: 0.0440 - val_accuracy: 0.9667 - 108ms/epoch - 22ms/step
# Epoch 45/100
# 5/5 - 0s - loss: 0.1538 - accuracy: 0.9667 - val_loss: 0.0309 - val_accuracy: 1.0000 - 103ms/epoch - 21ms/step
# Epoch 46/100
# 5/5 - 0s - loss: 0.0715 - accuracy: 0.9778 - val_loss: 0.0436 - val_accuracy: 0.9667 - 109ms/epoch - 22ms/step
# Epoch 47/100
# 5/5 - 0s - loss: 0.0733 - accuracy: 0.9667 - val_loss: 0.0420 - val_accuracy: 0.9667 - 100ms/epoch - 20ms/step
# Epoch 48/100
# 5/5 - 0s - loss: 0.1005 - accuracy: 0.9778 - val_loss: 0.0355 - val_accuracy: 0.9667 - 114ms/epoch - 23ms/step
# Epoch 49/100
# 5/5 - 0s - loss: 0.2107 - accuracy: 0.9556 - val_loss: 0.0335 - val_accuracy: 0.9667 - 96ms/epoch - 19ms/step
# Epoch 50/100
# 5/5 - 0s - loss: 0.0823 - accuracy: 0.9667 - val_loss: 0.0310 - val_accuracy: 1.0000 - 96ms/epoch - 19ms/step
# Epoch 51/100
# 5/5 - 0s - loss: 0.0916 - accuracy: 0.9778 - val_loss: 0.0337 - val_accuracy: 0.9667 - 112ms/epoch - 22ms/step
# Epoch 52/100
# 5/5 - 0s - loss: 0.0643 - accuracy: 0.9778 - val_loss: 0.0338 - val_accuracy: 0.9667 - 99ms/epoch - 20ms/step
# Epoch 53/100
# 5/5 - 0s - loss: 0.0457 - accuracy: 0.9889 - val_loss: 0.0313 - val_accuracy: 1.0000 - 107ms/epoch - 21ms/step
# Epoch 54/100
# 5/5 - 0s - loss: 0.1035 - accuracy: 0.9778 - val_loss: 0.0355 - val_accuracy: 0.9667 - 130ms/epoch - 26ms/step
# Epoch 55/100
# 5/5 - 0s - loss: 0.1057 - accuracy: 0.9778 - val_loss: 0.0299 - val_accuracy: 1.0000 - 97ms/epoch - 19ms/step
# Epoch 56/100
# 5/5 - 0s - loss: 0.0604 - accuracy: 0.9889 - val_loss: 0.0258 - val_accuracy: 1.0000 - 102ms/epoch - 20ms/step
# Epoch 57/100
# 5/5 - 0s - loss: 0.0769 - accuracy: 0.9778 - val_loss: 0.0223 - val_accuracy: 1.0000 - 93ms/epoch - 19ms/step
# Epoch 58/100
# 5/5 - 0s - loss: 0.0422 - accuracy: 0.9889 - val_loss: 0.0139 - val_accuracy: 1.0000 - 93ms/epoch - 19ms/step
# Epoch 59/100
# 5/5 - 0s - loss: 0.0415 - accuracy: 0.9889 - val_loss: 0.0211 - val_accuracy: 1.0000 - 92ms/epoch - 18ms/step
# Epoch 60/100
# 5/5 - 0s - loss: 0.0802 - accuracy: 0.9889 - val_loss: 0.0252 - val_accuracy: 1.0000 - 100ms/epoch - 20ms/step
# Epoch 61/100
# 5/5 - 0s - loss: 0.0702 - accuracy: 0.9889 - val_loss: 0.0088 - val_accuracy: 1.0000 - 90ms/epoch - 18ms/step
# Epoch 62/100
# 5/5 - 0s - loss: 0.1093 - accuracy: 0.9667 - val_loss: 0.0108 - val_accuracy: 1.0000 - 99ms/epoch - 20ms/step
# Epoch 63/100
# 5/5 - 0s - loss: 0.0625 - accuracy: 0.9889 - val_loss: 0.0123 - val_accuracy: 1.0000 - 88ms/epoch - 18ms/step
# Epoch 64/100
# 5/5 - 0s - loss: 0.0687 - accuracy: 0.9667 - val_loss: 0.0526 - val_accuracy: 0.9667 - 88ms/epoch - 18ms/step
# Epoch 65/100
# 5/5 - 0s - loss: 0.1101 - accuracy: 0.9667 - val_loss: 0.0603 - val_accuracy: 0.9667 - 99ms/epoch - 20ms/step
# Epoch 66/100
# 5/5 - 0s - loss: 0.1225 - accuracy: 0.9778 - val_loss: 0.0397 - val_accuracy: 0.9667 - 86ms/epoch - 17ms/step
# Epoch 67/100
# 5/5 - 0s - loss: 0.1393 - accuracy: 0.9667 - val_loss: 0.0128 - val_accuracy: 1.0000 - 96ms/epoch - 19ms/step
# Epoch 68/100
# 5/5 - 0s - loss: 0.0971 - accuracy: 0.9667 - val_loss: 0.0154 - val_accuracy: 1.0000 - 89ms/epoch - 18ms/step
# Epoch 69/100
# 5/5 - 0s - loss: 0.0655 - accuracy: 0.9778 - val_loss: 0.0436 - val_accuracy: 0.9667 - 104ms/epoch - 21ms/step
# Epoch 70/100
# 5/5 - 0s - loss: 0.0877 - accuracy: 0.9667 - val_loss: 0.0477 - val_accuracy: 0.9667 - 90ms/epoch - 18ms/step
# Epoch 71/100
# 5/5 - 0s - loss: 0.0707 - accuracy: 0.9889 - val_loss: 0.0433 - val_accuracy: 0.9667 - 105ms/epoch - 21ms/step
# Epoch 72/100
# 5/5 - 0s - loss: 0.0626 - accuracy: 0.9889 - val_loss: 0.0345 - val_accuracy: 0.9667 - 91ms/epoch - 18ms/step
# Epoch 73/100
# 5/5 - 0s - loss: 0.0652 - accuracy: 0.9889 - val_loss: 0.0180 - val_accuracy: 1.0000 - 87ms/epoch - 17ms/step
# Epoch 74/100
# 5/5 - 0s - loss: 0.0475 - accuracy: 0.9889 - val_loss: 0.0265 - val_accuracy: 1.0000 - 96ms/epoch - 19ms/step
# Epoch 75/100
# 5/5 - 0s - loss: 0.0691 - accuracy: 0.9667 - val_loss: 0.0435 - val_accuracy: 0.9667 - 85ms/epoch - 17ms/step
# Epoch 76/100
# 5/5 - 0s - loss: 0.1325 - accuracy: 0.9556 - val_loss: 0.0573 - val_accuracy: 0.9667 - 101ms/epoch - 20ms/step
# Epoch 77/100
# 5/5 - 0s - loss: 0.0893 - accuracy: 0.9778 - val_loss: 0.0388 - val_accuracy: 0.9667 - 97ms/epoch - 19ms/step
# Epoch 78/100
# 5/5 - 0s - loss: 0.1290 - accuracy: 0.9556 - val_loss: 0.0408 - val_accuracy: 0.9667 - 178ms/epoch - 36ms/step
# Epoch 79/100
# 5/5 - 0s - loss: 0.1132 - accuracy: 0.9444 - val_loss: 0.0406 - val_accuracy: 0.9667 - 135ms/epoch - 27ms/step
# Epoch 80/100
# 5/5 - 0s - loss: 0.1052 - accuracy: 0.9778 - val_loss: 0.0329 - val_accuracy: 1.0000 - 128ms/epoch - 26ms/step
# Epoch 81/100
# 5/5 - 0s - loss: 0.1251 - accuracy: 0.9778 - val_loss: 0.0306 - val_accuracy: 1.0000 - 216ms/epoch - 43ms/step
# Epoch 82/100
# 5/5 - 0s - loss: 0.0774 - accuracy: 0.9889 - val_loss: 0.0326 - val_accuracy: 1.0000 - 149ms/epoch - 30ms/step
# Epoch 83/100
# 5/5 - 0s - loss: 0.0793 - accuracy: 0.9778 - val_loss: 0.0189 - val_accuracy: 1.0000 - 113ms/epoch - 23ms/step
# Epoch 84/100
# 5/5 - 0s - loss: 0.1043 - accuracy: 0.9444 - val_loss: 0.0163 - val_accuracy: 1.0000 - 130ms/epoch - 26ms/step
# Epoch 85/100
# 5/5 - 0s - loss: 0.0912 - accuracy: 0.9778 - val_loss: 0.0167 - val_accuracy: 1.0000 - 173ms/epoch - 35ms/step
# Epoch 86/100
# 5/5 - 0s - loss: 0.1088 - accuracy: 0.9667 - val_loss: 0.0293 - val_accuracy: 1.0000 - 151ms/epoch - 30ms/step
# Epoch 87/100
# 5/5 - 0s - loss: 0.0874 - accuracy: 0.9778 - val_loss: 0.0380 - val_accuracy: 0.9667 - 177ms/epoch - 35ms/step
# Epoch 88/100
# 5/5 - 0s - loss: 0.0742 - accuracy: 0.9778 - val_loss: 0.0432 - val_accuracy: 0.9667 - 128ms/epoch - 26ms/step
# Epoch 89/100
# 5/5 - 0s - loss: 0.1583 - accuracy: 0.9667 - val_loss: 0.0450 - val_accuracy: 0.9667 - 186ms/epoch - 37ms/step
# Epoch 90/100
# 5/5 - 0s - loss: 0.1094 - accuracy: 0.9667 - val_loss: 0.0518 - val_accuracy: 0.9667 - 149ms/epoch - 30ms/step
# Epoch 91/100
# 5/5 - 0s - loss: 0.0685 - accuracy: 0.9667 - val_loss: 0.0512 - val_accuracy: 0.9667 - 163ms/epoch - 33ms/step
# Epoch 92/100
# 5/5 - 0s - loss: 0.1172 - accuracy: 0.9667 - val_loss: 0.0369 - val_accuracy: 0.9667 - 187ms/epoch - 37ms/step
# Epoch 93/100
# 5/5 - 0s - loss: 0.1341 - accuracy: 0.9667 - val_loss: 0.0232 - val_accuracy: 1.0000 - 114ms/epoch - 23ms/step
# Epoch 94/100
# 5/5 - 0s - loss: 0.1801 - accuracy: 0.9333 - val_loss: 0.0291 - val_accuracy: 1.0000 - 159ms/epoch - 32ms/step
# Epoch 95/100
# 5/5 - 0s - loss: 0.1097 - accuracy: 0.9556 - val_loss: 0.0383 - val_accuracy: 0.9667 - 151ms/epoch - 30ms/step
# Epoch 96/100
# 5/5 - 0s - loss: 0.1077 - accuracy: 0.9889 - val_loss: 0.0348 - val_accuracy: 0.9667 - 107ms/epoch - 21ms/step
# Epoch 97/100
# 5/5 - 0s - loss: 0.0846 - accuracy: 0.9667 - val_loss: 0.0236 - val_accuracy: 1.0000 - 93ms/epoch - 19ms/step
# Epoch 98/100
# 5/5 - 0s - loss: 0.1331 - accuracy: 0.9556 - val_loss: 0.0283 - val_accuracy: 1.0000 - 96ms/epoch - 19ms/step
# Epoch 99/100
# 5/5 - 0s - loss: 0.1410 - accuracy: 0.9444 - val_loss: 0.0324 - val_accuracy: 0.9667 - 114ms/epoch - 23ms/step
# Epoch 100/100
# 5/5 - 0s - loss: 0.1051 - accuracy: 0.9556 - val_loss: 0.0387 - val_accuracy: 0.9667 - 125ms/epoch - 25ms/step

# %% [markdown]
# ### Plot the learning curves

# %%
plot_metric(history, 'loss')

# %% [markdown]
# Here, you can see that the overfitting is not completely fixed, but there is a signficant improvement when we compare it to the unregularized model

# %%
# Evaluate the model on the test set
model.evaluate(X_test, y_test, verbose=2)
# Out:
# 1/1 - 0s - loss: 0.0716 - accuracy: 0.9667 - 39ms/epoch - 39ms/step
# [0.07159223407506943, 0.9666666388511658]
