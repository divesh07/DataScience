# %%
from sklearn.manifold import TSNE
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
data_X = digits.data[:600]
y = digits.target[:600]
data_X.shape
# Out:
# (600, 64)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
PC = pca.fit_transform(data_X)

# %%
tsne_df = pd.DataFrame({'X':PC[:,0],
                        'Y':PC[:,1],
                        'digit':y})
tsne_df.head()
# Out:
#            X          Y  digit
# 0 -18.883534   2.293900      0
# 1  21.814215   0.110376      1
# 2  12.952824   3.437548      2
# 3 -10.212209  -8.320956      3
# 4  15.606466  14.933917      4

# %%
sns.scatterplot(x="X", y="Y",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne_df);

# %%
tsne = TSNE(n_components=2, random_state=0)

# %%
tsne_obj= tsne.fit_transform(data_X)

# %%
tsne_obj.shape
# Out:
# (600, 2)

# %%
tsne_df = pd.DataFrame({'X':tsne_obj[:,0],
                        'Y':tsne_obj[:,1],
                        'digit':y})
tsne_df.head()
# Out:
#            X          Y  digit
# 0  35.729576 -15.248073      0
# 1 -19.279284  -6.898149      1
# 2 -15.420641   0.944377      2
# 3  22.055639   9.480317      3
# 4 -33.239338  -2.813015      4

# %%
sns.scatterplot(x="X", y="Y",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne_df);
