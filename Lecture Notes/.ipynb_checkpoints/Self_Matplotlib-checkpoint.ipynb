# %%
# Graph plotting library
import matplotlib as plt
plt.__version__
# Out:
# '3.7.2'

# %%
import numpy as np
import pandas as pd

# %%
# user functions
'''
plot()  - plotting the graph
show() - display the graph
title() - label
xlabel() - axis label
ylabel()
'''

# %%
sample = pd.read_excel('sample.xlsx')
sample
# Out:
#       Name  Age Gender  Salary
# 0    Harry   25      M   10000
# 1   Potter   26      M   20000
# 2     Joey   25      M   30000
# 3    Ronny   29      M   50000
# 4     John   28      M   45000
# 5   Monica   21      F   35000
# 6     Nick   30      M   28000
# 7    Karen   35      F   31000
# 8    Susan   30      F   32000
# 9     Emma   36      F   52000
# 10   Linda   29      F   55000
# 11    Jack   23      M   25000
# 12   Emily   21      F   41000
# 13    Noah   33      M   42000
# 14   Jacob   34      M   55000

# %%
sample.plot(x='Age', y='Salary', kind ='bar', hatch=".")
# Out:
# <Axes: xlabel='Age'>

# %%
sample.plot(x='Age', y='Salary', kind = 'scatter', hatch = '//', s=100)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sample.plot(x='Age', y='Salary', kind = 'line')
# Out:
# <Axes: xlabel='Age'>

# %%
import matplotlib.pyplot as plt

# Create a figure containing a single axes
fig, ax = plt.subplots()

# Plot data on the axes
ax.plot([1,2,3,4], [10,20,90,40])

# %%
#Figure
fig = plt.figure() # empty figure with no axes
fig , ax = plt.subplots() # figure with single axis

# %%
fig, axs = plt.subplot_mosaic([['left','right'], ['left','right']])

# %%
fig , axs = plt.subplots(2,2)b

# %%
b = np.matrix([[1,2], [3,4]])
np.asarray(b)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
# Create multiple subplots
fig , ((ax1), (ax2)) = plt.subplots(nrows=1, ncols=2, figsize=(5,5))

ax1.hist(sample['Salary'], bins='auto', alpha= 0.4)
ax2.hist(sample['Age'], bins='auto', alpha= 0.8)
# Out:
# (array([3., 3., 3., 2., 4.]),
#  array([21., 24., 27., 30., 33., 36.]),
#  <BarContainer object of 5 artists>)

# %%
#Overlapping the plots
import numpy as np
